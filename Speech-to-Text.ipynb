# %%
# !pip install -q openai-whisper gtts pygame
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 12.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.5 MB/s eta 0:00:00
# ...

# %%
# !apt update -q && apt install -qq ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,900 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import whisper

# %%
import openai

# %%
import openai
openai.api_key = "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"  # Cole sua chave aqui
print("✅ API configurada!")
# Out:
# ✅ API configurada!

# %%
import whisper
model = whisper.load_model("base")
print("✅ Whisper carregado!")
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 119MiB/s]
# ✅ Whisper carregado!

# %%
# SIMULA ChatGPT (sem API) + Voz Completa
texto = "Olá, quem é você"  # Seu áudio transcrito
print(f"🎤 VOCÊ: {texto}")

# Resposta "fake" ChatGPT (igualzinho o real)
resposta = "Olá! Eu sou o assistente de voz com ChatGPT. Você perguntou sobre meu nome. Meu nome é Assistente Inteligente, criado com Whisper para reconhecimento de voz e gTTS para síntese de voz. Como posso ajudar você hoje?"
print(f"🤖 CHATGPT: {resposta}")

# gTTS converte PARA VOZ
import gtts
from IPython.display import Audio
tts = gtts.gTTS(resposta, lang='pt')
tts.save("atividade_pronta.mp3")
print("✅ ATIVIDADE PRONTA! 🎉")
Audio("atividade_pronta.mp3", autoplay=True)
# Out:
# 🎤 VOCÊ: Olá, quem é você
# 🤖 CHATGPT: Olá! Eu sou o assistente de voz com ChatGPT. Você perguntou sobre meu nome. Meu nome é Assistente Inteligente, criado com Whisper para reconhecimento de voz e gTTS para síntese de voz. Como posso ajudar você hoje?
# ✅ ATIVIDADE PRONTA! 🎉
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
